# %%
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
import numpy as np
import cvxpy as cp

# %%
sentiments = {
    'Obsidian': '---',
    'Pyroflex': '---',
    'Thermalite': '++++',
    'Ashes': '-',
    'cake': '---',
    'Magma': '++++',
    'Scoria': '++',
    'Volcanic': '++',
    'Sulfur': '+++'
}

returns = {
    '+': 0.05,
    '++': 0.15,
    '+++': 0.25,
    '++++': 0.35,
    '-': -0.05,
    '--': -0.1,
    '---': -0.4,
    '----': -0.6
}

products = list(sentiments.keys())
print("Products:", products)
# Out:
# Products: ['Obsidian', 'Pyroflex', 'Thermalite', 'Ashes', 'cake', 'Magma', 'Scoria', 'Volcanic', 'Sulfur']

# %%
rets = np.array([returns[sentiments[products[i-1]]] for i in range(1,10)])
pi = cp.Variable(9)
objective = cp.Minimize(100 * cp.sum_squares(pi) - 10000 * rets.T @ pi)
constraints = [cp.norm(pi, 1) <= 100]
prob = cp.Problem(objective, constraints)

prob.solve()
print('Optimal allocation without integer constraints:')
for i in range(9):
    print("Position in ", products[i], ': ', f"{pi.value[i]:,.2f}", '%', sep='')
# Out:
# Optimal allocation without integer constraints:
# Position in Obsidian: -17.19%
# Position in Pyroflex: -17.19%
# Position in Thermalite: 14.69%
# Position in Ashes: 0.00%
# Position in cake: -17.19%
# Position in Magma: 14.69%
# Position in Scoria: 4.69%
# Position in Volcanic: 4.69%
# Position in Sulfur: 9.69%

# %%
#building blocks for the Mathematica command
s1 = ' + '.join(['('+str(returns[sentiments[products[i-1]]])+')*p'+str(i)+'*10000-100*(p'+str(i)+')^2' for i in range(1,10)])
s2 = ' + '.join(['Abs[p'+str(i)+']' for i in range(1,10)]) + '<=100,'
s3 = ', '.join(['Element[p'+str(i)+', Integers]' for i in range(1,10)])
s4 = ', '.join(['p'+str(i) for i in range(1,10)])

# %%
'NMaximize[{'+s1+','+s2+s3+'}, {'+s4+'}]'
# Out:
# 'NMaximize[{(-0.4)*p1*10000-100*(p1)^2 + (-0.4)*p2*10000-100*(p2)^2 + (0.35)*p3*10000-100*(p3)^2 + (-0.05)*p4*10000-100*(p4)^2 + (-0.4)*p5*10000-100*(p5)^2 + (0.35)*p6*10000-100*(p6)^2 + (0.15)*p7*10000-100*(p7)^2 + (0.15)*p8*10000-100*(p8)^2 + (0.25)*p9*10000-100*(p9)^2,Abs[p1] + Abs[p2] + Abs[p3] + Abs[p4] + Abs[p5] + Abs[p6] + Abs[p7] + Abs[p8] + Abs[p9]<=100,Element[p1, Integers], Element[p2, Integers], Element[p3, Integers], Element[p4, Integers], Element[p5, Integers], Element[p6, Integers], Element[p7, Integers], Element[p8, Integers], Element[p9, Integers]}, {p1, p2, p3, p4, p5, p6, p7, p8, p9}]'

# %%
session = WolframLanguageSession(startup_timeout=60)  # 60 seconds
try:
    val_max, sol = session.evaluate(wlexpr('NMaximize[{'+s1+','+s2+s3+'}, {'+s4+'}]'))
finally:
    session.terminate()
# Out:
# Socket exception: Socket operation aborted.
# Failed to start.
# ---------------------------------------------------------------------------
# SocketAborted                             Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/kernelcontroller.py:445, in WolframKernelController._kernel_start(self)
#     442 try:
#     443     # First message must be "OK", acknowledging everything is up and running
#     444     # on the kernel side.
# --> 445     response = self.kernel_socket_in.recv_abortable(
#     446         timeout=self.get_parameter("STARTUP_TIMEOUT"),
#     447         abort_event=self._new_running_event(),
#     448     )
#     449     if response == self._KERNEL_OK:
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/zmqsocket.py:49, in abortable.<locals>.outer.<locals>.recv_abortable(socket, timeout, abort_check_period, abort_event, **kwargs)
#      48 if abort_event and abort_event.is_set():
# ---> 49     raise SocketAborted("Socket operation aborted.")
#      50 if timeout and (time.perf_counter() - start > timeout):
#
# SocketAborted: Socket operation aborted.
#
# During handling of the above exception, another exception occurred:
#
# WolframKernelException                    Traceback (most recent call last)
# Cell In[9], line 3
#       1 session = WolframLanguageSession(startup_timeout=60)  # 60 seconds
#       2 try:
# ----> 3     val_max, sol = session.evaluate(wlexpr('NMaximize[{'+s1+','+s2+s3+'}, {'+s4+'}]'))
#       4 finally:
#       5     session.terminate()
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:263, in WolframLanguageSession.evaluate(self, expr, **kwargs)
#     262 def evaluate(self, expr, **kwargs):
# --> 263     result = self.evaluate_wrap(expr, **kwargs)
#     264     self.log_message_from_result(result)
#     265     return result.get()
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:260, in WolframLanguageSession.evaluate_wrap(self, expr, **kwargs)
#     259 def evaluate_wrap(self, expr, **kwargs):
# --> 260     return self.evaluate_wrap_future(expr, **kwargs).result()
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:256, in WolframLanguageSession.evaluate_wrap_future(self, expr, **kwargs)
#     250 def evaluate_wrap_future(self, expr, **kwargs):
#     251     """Evaluate an expression and return a future object.
#     252
#     253     The future object result is the result object with the evaluated expression and meta information.
#     254     See :func:`~wolframclient.evaluation.WolframLanguageSession.evaluate_wrap`.
#     255     """
# --> 256     self.ensure_started()
#     257     return self.do_evaluate_future(expr, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:207, in WolframLanguageSession.ensure_started(self)
#     205 def ensure_started(self):
#     206     if not self.started:
# --> 207         self.start(block=True, timeout=None)
#     208     if self.stopped:
#     209         self.restart()
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:157, in WolframLanguageSession.start(self, block, timeout)
#     155     self.terminate()
#     156 finally:
# --> 157     raise e
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/localsession.py:152, in WolframLanguageSession.start(self, block, timeout)
#     150     future = self.start_future()
#     151     if future and block:
# --> 152         future.result(timeout=timeout)
#     153 except Exception as e:
#     154     try:
#
# File /opt/anaconda3/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /opt/anaconda3/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/kernelcontroller.py:568, in WolframKernelController.run(self)
#     566 # Kernel start requested.
#     567 if payload is self.START:
# --> 568     self._safe_kernel_start()
#     569     future.set_result(True)
#     570     future = None
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/kernelcontroller.py:370, in WolframKernelController._safe_kernel_start(self)
#     368     self._kernel_terminate()
#     369 finally:
# --> 370     raise e
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/kernelcontroller.py:364, in WolframKernelController._safe_kernel_start(self)
#     362 """Start a kernel. If something went wrong, clean-up resources that may have been created."""
#     363 try:
# --> 364     self._kernel_start()
#     365 except Exception as e:
#     366     logger.warning("Failed to start.")
#
# File /opt/anaconda3/lib/python3.13/site-packages/wolframclient/evaluation/kernel/kernelcontroller.py:466, in WolframKernelController._kernel_start(self)
#     462     raise WolframKernelException(
#     463         "Wolfram kernel version is not supported. Please consult library prerequisites."
#     464     )
#     465 logger.warning("Socket exception: %s", se)
# --> 466 raise WolframKernelException(
#     467     "Failed to communicate with kernel: %s." % self.kernel
#     468 )
#
# WolframKernelException: Failed to communicate with kernel: /Applications/Wolfram Engine.app/Contents/MacOS/WolframKernel.
